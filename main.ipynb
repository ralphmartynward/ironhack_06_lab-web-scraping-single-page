# %% [markdown]
# # Lab | Web Scraping Single Page

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
url = "https://www.billboard.com/charts/hot-100/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
[elem.get_text() for elem in soup.find_all("h3", {"id":"title-of-a-story"})]

# %%
soup.find_all("h3")
# Out:
# [<h3 class="c-title a-font-primary-bold-l a-font-primary-bold-m@mobile-max lrv-u-color-black u-color-white@mobile-max lrv-u-margin-r-150" id="">
#  <a class="c-title__link lrv-a-unstyle-link" href="#">
#
#
#  					Kill Bill
#  					</a>
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-s u-letter-spacing-0021" id="title-of-a-story">
#
#
#
#
#  					Songwriter(s):
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-s u-letter-spacing-0021" id="title-of-a-story">
#
#
#
#
#  					Producer(s):
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-s u-letter-spacing-0021" id="title-of-a-story">
#
#
#
#
#  					Imprint/Promotion Label:
#
#  </h3>,
#  <h3 class="c-title a-font-primary-m lrv-u-color-brand-primary:hover" id="title-of-a-story">
#  <a class="c-title__link lrv-a-unstyle-link" href="https://www.billboard.com/music/chart-beat/sza-kill-bill-number-one-five-burning-questions-1235314777/">
#
#
#  					How Meaningful Is It for SZA That 'Kill Bill' Finally Hit No. 1?
# ...

# %%
soup.find_all("h3", {"class":"c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"})
# Out:
# [<h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Last Night
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Flowers
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Princess Diana
#
#  </h3>,
# ...

# %%
for elem in soup.find_all("h3", {"class":"c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"}):
    print(elem.get_text())
# Out:
#
#
#
# 					Last Night
#
#
#
#
#
#
#
# 					Flowers
#
#
#
#
#
#
#
# 					Princess Diana
#
#
#
#
#
#
#
# 					Ella Baila Sola
#
#
#
#
#
#
#
# 					Creepin'
#
#
#
#
#
#
#
# 					Calm Down
#
#
#
#
#
#
#
# 					Die For You
#
#
#
#
#
#
#
# 					Search & Rescue
#
#
#
#
#
#
#
# 					Boy's A Liar, Pt. 2
#
#
#
#
#
#
#
# 					Anti-Hero
#
#
#
#
#
#
#
# 					La Bebe
#
#
#
#
#
#
#
# 					Chemical
#
#
#
#
#
#
#
# 					Favorite Song
#
#
#
#
#
#
#
# 					Un x100to
#
#
#
#
#
#
#
# 					Players
#
#
#
#
#
#
#
# 					Rock And A Hard Place
#
#
#
#
#
#
#
# 					You Proof
#
#
#
#
#
#
#
# 					Fast Car
#
#
#
#
#
#
#
# 					Sure Thing
#
#
#
#
#
#
#
# 					As It Was
#
#
#
#
#
#
#
# 					Thinkin' Bout Me
#
#
#
#
#
#
#
# 					Lavender Haze
#
#
#
#
#
#
#
# 					One Thing At A Time
#
#
#
#
#
#
#
# 					Thought You Should Know
#
#
#
#
#
#
#
# 					I'm Good (Blue)
#
#
#
#
#
#
#
# 					Under The Influence
#
#
#
#
#
#
#
# 					Thank God
#
#
#
#
#
#
#
# 					Something In The Orange
#
#
#
#
#
#
#
# 					Escapism
#
#
#
# ...

# %%
soup.find_all("span", {"class":"c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"})
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Morgan Wallen
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Miley Cyrus
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Ice Spice &amp; Nicki Minaj
#  </span>,
# ...

# %%
def scrape_hot100():
    url = 'https://www.billboard.com/charts/hot-100'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all song title and artist elements
    song_titles = soup.find_all("h3", {"class":"c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"})

    song_artists = soup.find_all("span", {"class":"c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"})

    # Extract and clean song titles and artists
    cleaned_song_titles = [title.text.strip() for title in song_titles]
    cleaned_song_artists = [artist.text.strip() for artist in song_artists]

    # Create a pandas DataFrame
    hot100_df = pd.DataFrame({'Song': cleaned_song_titles, 'Artist': cleaned_song_artists})

    # Save the DataFrame to a CSV file
    hot100_df.to_csv('hot100_songs.csv', index=False)

# Call the function to scrape and save the data
scrape_hot100()

# %%
# read the csv file
hot100_df = pd.read_csv('hot100_songs.csv')
hot100_df.head(100)
# Out:
#                  Song                                   Artist
# 0          Last Night                            Morgan Wallen
# 1             Flowers                              Miley Cyrus
# 2      Princess Diana                  Ice Spice & Nicki Minaj
# 3     Ella Baila Sola              Eslabon Armado X Peso Pluma
# 4            Creepin'     Metro Boomin, The Weeknd & 21 Savage
# ..                ...                                      ...
# 94        Memory Lane                             Old Dominion
# 95         Love Again                            The Kid LAROI
# 96         '98 Braves                            Morgan Wallen
# 97          Di Que Si  Grupo Marca Registrada X Grupo Frontera
# 98  It Matters To Her                          Scotty McCreery
#
# [99 rows x 2 columns]

# %%
def scrape_hot100():
    url = "https://www.billboard.com/charts/hot-100/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    song_elements = soup("div", class_="o-chart-results-list-row-container")
    #print("song_elements:", song_elements)
    
    songs = []
    for element in song_elements:
        song = {}
        song["title"] = element.find("h3").text.strip()
        song["artist"] = element.find("h3").find_next("span").text.strip()
        songs.append(song)
    
    #print("songs:", songs)
    
    hot100_df = pd.DataFrame(songs)
    return hot100_df

    # Save the DataFrame to a CSV file
    hot100_df.to_csv('hot100_songs.csv', index=False)

hot100_df = scrape_hot100()
hot100_df.head()
# Out:
#              title                       artist
# 0        Kill Bill                          SZA
# 1       Last Night                Morgan Wallen
# 2          Flowers                  Miley Cyrus
# 3   Princess Diana      Ice Spice & Nicki Minaj
# 4  Ella Baila Sola  Eslabon Armado X Peso Pluma

# %% [markdown]
# Ok nice, now let's get this into a tinydb database json file instead

# %%
from tinydb import TinyDB, Query
db = TinyDB('hot100.json')
db.insert_multiple(hot100_df.to_dict('records'))

# %%
# check the db in a dataframe
df = pd.DataFrame(db.all())
df.head()
# Out:
#              title                       artist
# 0        Kill Bill                          SZA
# 1       Last Night                Morgan Wallen
# 2          Flowers                  Miley Cyrus
# 3   Princess Diana      Ice Spice & Nicki Minaj
# 4  Ella Baila Sola  Eslabon Armado X Peso Pluma
